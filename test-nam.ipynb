# %%
import pandas as pd

data = pd.read_pickle('/user/iibi/nale/iiai-projects/G-Bert/data/data-multi-visit.pkl')

# %%
data
# Out:
#        SUBJECT_ID  HADM_ID                                          ICD9_CODE  \
# 0              17   161087  [4239, 5119, 78551, 4589, 311, 7220, 71946, 2724]
# 1              17   194023                         [7455, 45829, V1259, 2724]
# 2              21   109451  [41071, 78551, 5781, 5849, 40391, 4280, 4592, ...
# 3              21   111970  [0388, 78552, 40391, 42731, 70709, 5119, 6823,...
# 4              23   124321  [2252, 3485, 78039, 4241, 4019, 2720, 2724, V4...
# ...           ...      ...                                                ...
# 15011       99923   164914  [45829, 4532, 2761, 5723, 4561, 45621, 5849, 7...
# 15012       99923   192053  [5712, 5856, 5724, 40391, 9974, 5601, 30393, V...
# 15013       99982   112748  [4280, 42823, 5849, 4254, 2763, 42731, 78729, ...
# 15014       99982   151454  [42823, 4254, 2875, 42731, 3970, 5303, 4280, V...
# 15015       99982   183791  [5849, 42731, 4280, 2875, 53081, 56400, 78720,...
#
# ...
